# %%
# bibliotecas
import telebot as tb
from telebot.types import InlineKeyboardMarkup, InlineKeyboardButton, WebAppInfo
import json

# %%
chave_api = "8620872096:AAFSiPOSsmnsUqUDhSOJhLfDusRqq9V2mXA"
bot = tb.TeleBot(chave_api)

# --- 1. COMANDO START ---
@bot.message_handler(commands=['start'])
def boasvindas(mensagem):
    teclado = InlineKeyboardMarkup()
    url_mini_app = "https://annabeatriz9572.github.io/Testes-Inicia-o-cientifica/" 
    botao_scanner = InlineKeyboardButton(
        text="📷 Escanear CRM", 
        web_app=WebAppInfo(url=url_mini_app)
    )
    teclado.add(botao_scanner)
    texto = 'Olá bem vindo ao chatbot de testes da IC 2025-2026 de Anna Beatriz e Luiz Felipe!'
    bot.reply_to(mensagem, texto, reply_markup=teclado)


# --- 2. NOVO: RECEBER OS DADOS DO MINI APP ---
@bot.message_handler(content_types=['web_app_data'])
def receber_dados(mensagem):
    # Pega o "pacotinho" de texto enviado pelo site e transforma em variáveis no Python
    dados_recebidos = mensagem.web_app_data.data
    pacote = json.loads(dados_recebidos)
    
    cpf_digitado = pacote.get("cpf")
    senha_digitada = pacote.get("senha")
    qr_code_lido = pacote.get("qr_code")

    # --- SIMULAÇÃO DA API ---
    # No futuro do projeto, aqui entrará a conexão via "requests" para validação 
    # na API dos Conselhos Regionais de Medicina (CRM).
    # Por enquanto, teste o sucesso com CPF 123 e Senha 456 no seu Mini App!
    
    if cpf_digitado == "123" and senha_digitada == "456":
        
        texto_sucesso = f"✅ Identidade validada com sucesso!\n\nDados lidos no QR Code:\n{qr_code_lido}"
        bot.send_message(mensagem.chat.id, texto_sucesso)
        
    else:
        
        # Cria o botão de novo para o caso de erro
        teclado_erro = InlineKeyboardMarkup()
        url_mini_app = "https://annabeatriz9572.github.io/Testes-Inicia-o-cientifica/" 
        botao_tentar = InlineKeyboardButton(
            text="🔄 Tentar Novamente", 
            web_app=WebAppInfo(url=url_mini_app)
        )
        teclado_erro.add(botao_tentar)
        
        texto_erro = "❌ Erro na autenticação: CPF ou Senha não conferem. Por favor, tente novamente."
        bot.send_message(mensagem.chat.id, texto_erro, reply_markup=teclado_erro)


# --- 3. MOTOR DO BOT (Sempre a última linha) ---
bot.infinity_polling()
# Out:
# 2026-04-05 12:56:00,707 (__init__.py:1115 MainThread) ERROR - TeleBot: "Infinity polling exception: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=30)"
# 2026-04-05 12:56:00,944 (__init__.py:1117 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py", line 571, in getresponse
#     httplib_response = super().getresponse()
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\http\client.py", line 1450, in getresponse
#     response.begin()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\http\client.py", line 336, in begin
#     version, status, reason = self._read_status()
#                               ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\http\client.py", line 297, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\socket.py", line 725, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\ssl.py", line 1304, in recv_into
#     return self.read(nbytes, buffer)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\ssl.py", line 1138, in read
#     return self._sslobj.read(len, buffer)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\adapters.py", line 645, in send
#     resp = conn.urlopen(
#         method=request.method,
#     ...<9 lines>...
#         chunked=chunked,
#     )
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#         method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     )
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\retry.py", line 490, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\util.py", line 39, in reraise
#     raise value
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#         conn,
#     ...<10 lines>...
#         **response_kw,
#     )
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py", line 367, in _raise_timeout
#     raise ReadTimeoutError(
#         self, url, f"Read timed out. (read timeout={timeout_value})"
#     ) from err
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\telebot\__init__.py", line 1110, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                  logger_level=logger_level, allowed_updates=allowed_updates, restart_on_change=False,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                  *args, **kwargs)
#                  ^^^^^^^^^^^^^^^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\telebot\__init__.py", line 1195, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\telebot\__init__.py", line 306, in user
#     self._user = self.get_me()
#                  ~~~~~~~~~~~^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\telebot\__init__.py", line 1382, in get_me
#     apihelper.get_me(self.token)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\telebot\apihelper.py", line 204, in get_me
#     return _make_request(token, method_url)
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\telebot\apihelper.py", line 162, in _make_request
#     result = _get_req_session().request(
#         method, request_url, params=params, files=files,
#         timeout=(connect_timeout, read_timeout), proxies=proxy)
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\sessions.py", line 592, in request
#     resp = self.send(prep, **send_kwargs)
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\sessions.py", line 706, in send
#     r = adapter.send(request, **kwargs)
#   File "c:\Users\Annab\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\adapters.py", line 691, in send
#     raise ReadTimeout(e, request=request)
# requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=30)
# "
# 2026-04-05 13:20:01,246 (__init__.py:1121 MainThread) ERROR - TeleBot: "Infinity polling: polling exited"
# 2026-04-05 13:20:01,248 (__init__.py:1123 MainThread) ERROR - TeleBot: "Break infinity polling"
